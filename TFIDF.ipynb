# %%
from collections import Counter
import math

# %%
import psycopg2

con = psycopg2.connect(
  database="db_dsa", 
  user="udsa", 
  password="P@ssword2021", 
  host="92.242.58.173", 
  port="1984"
)

print("Database opened successfully")
# Out:
# Database opened successfully

# %%
import pandas as pd
cur = con.cursor()
cur.execute("SELECT * from PROJECTS")
rows = cur.fetchall()
column_names=["ID","NUMBER","VACANCIES","NAME","TYPE","TYPEDESC","TYPEID","STATUSID", "STATUSDESC","DIRECTIONHEAD","HEAD","DATACREATED","FACULTYID"]
df = pd.DataFrame(rows, columns=column_names)
df.head()
# Out:
#     ID  NUMBER  VACANCIES                                               NAME  \
# 0  205     NaN          2  Численное и аналитическое исследование эффекта...
# 1  208     NaN          3  Исследование механизмов образования, способов ...
# 2  215     NaN          1                  Разработка моста переменного тока
# 3  216     NaN          3  Разработка нательных антенн и излучателей для ...
# 4  218     NaN          0  Разработка глоссария физических терминов для м...
#
#         TYPE        TYPEDESC  TYPEID  STATUSID      STATUSDESC  \
# 0        nir             НИР       1         1  Готов к работе
# 1        nir             НИР       1         1  Готов к работе
# 2  soft-hard  Прогр-аппарат.       3         1  Готов к работе
# 3  soft-hard  Прогр-аппарат.       3         1  Готов к работе
# 4       soft          Прогр.       2         1  Готов к работе
#
#                   DIRECTIONHEAD                            HEAD  \
# 0  Данилов Владимир Григорьевич    Данилов Владимир Григорьевич
# 1                                                Грачев Николай
# 2                                             Балакин Станислав
# 3   Елизаров Андрей Альбертович                 Скуридин Андрей
# 4                                Гузенкова Александра Сергеевна
#
#            DATACREATED FACULTYID
# 0  08.05.2020 21:25:02      None
# 1  11.05.2020 14:07:40      None
# 2  13.05.2020 16:41:39      None
# 3  13.05.2020 17:00:19      None
# 4  13.05.2020 19:38:43      None

# %%
df1 = df[['NAME']]
df2 = df1.apply(lambda x: ';'.join(x.astype(str)), axis=1)
df_clean = pd.DataFrame({'clean': df2})
sent = [row.split(';') for row in df_clean['clean']]

# %%
def compute_tfidf(corpus):
    def compute_tf(text):
        tf_text = Counter(text)
        for i in tf_text:
            tf_text[i] = tf_text[i]/float(len(text))
        return tf_text
    def compute_idf(word, corpus):
        return math.log10(len(corpus)/sum([1.0 for i in corpus if word in i]))
    documents_list = []
    for text in corpus:
        tf_idf_dictionary = {}
        computed_tf = compute_tf(text)
        for word in computed_tf:
            tf_idf_dictionary[word] = computed_tf[word] * compute_idf(word, corpus)
        documents_list.append(tf_idf_dictionary)
    return documents_list

corpus = sent

print(compute_tfidf(corpus))
# Out:
# [{'Численное и аналитическое исследование эффекта Саффмана-Тейлора': 2.509202522331103}, {'Исследование механизмов образования, способов и средств подавления контактных помех радиоприему': 2.509202522331103}, {'Разработка моста переменного тока': 2.509202522331103}, {'Разработка нательных антенн и излучателей для интернета вещей': 2.509202522331103}, {'Разработка глоссария физических терминов для мультилингваперевода задач по физике различной сложности для иностранных слушателей подготовительных отделений': 2.509202522331103}, {'Умные примерочные III. Проект интеллектуальной RFID системы': 2.509202522331103}, {'Топологические приложения в магнитной гидродинамике': 2.509202522331103}, {'Разработка микроволновой установки для процесса отверждения полимерных композиционных материалов в виде труб': 2.509202522331103}, {'Cплайн-интерполяция и аппроксимация в SciPy': 2.509202522331103}, {'Перспективная геофизическая информационно-измерительная система на основе новых способов передачи данных': 2.509202522331103}, {'Аппаратно-программный комплекс калибровки с удалённым доступом средств измерения электрических величин': 2.509202522331103}, {'Библиотека демонстрационно-образовательных программ в среде Матлаб для курса "Аналитические и численные методы моделирования" : методы Монте Карло': 2.509202522331103}, {'Элементы сверхпроводящей спинтроники для применения в квантовой наноэлектронике': 2.2081725266671217}, {'Неоднородные электронные состояния в магнитных оксидах и графене': 2.509202522331103}, {'Сверхпроводниковый детектор с разрешением числа фотонов': 2.509202522331103}, {'Разработка макромодели МДП-транзистора с йоннолегированным каналом для проектирования фотоприемных БИС': 2.509202522331103}, {'Виртуальный лабораторный практикум по системам сбора данных': 2.509202522331103}, {'Сверхпроводящие наноэлектронные элементы с высокой величиной кинетической индуктивности': 2.509202522331103}, {'Экспериментальное исследование квантовых наноэлектронных систем при (сверх)низких температурах': 2.509202522331103}, {'Автоматизированный комплекс для измерения характеристик и экстракции параметров SPICE-модели партий МОП-транзисторов на основе тестера электронных компонентов серии «Формула»': 2.2081725266671217}, {'Разработка управляющей программы и инструкции для автоматизированного измерения параметров микросхем операционных усилителей с использованием тестера Формула-2к': 2.509202522331103}, {'Разработка базы данных по материалам для многослойных печатных плат': 2.509202522331103}, {'Атомистическое компьютерное моделирование структуры и динамики адсорбции ионов на поверхности портландита, Ca(OH)2, с применением силовых полей ClayFF-MOH и ReaxFF': 2.509202522331103}, {'Влияние параметров ферромагнетика на характеристики туннельных Джозефсоновских переходов с ферромагнитной прослойкой': 2.509202522331103}, {'Детектор одиночных фотонов на основе Джозефсоновского перехода для поиска аксионов тёмной материи': 2.509202522331103}, {'Разработка интерфейса пользователя для программы расчета безотказности сложных резервированных систем': 2.509202522331103}, {'Инструментальные средства для оценки качества связи в глобальной сети интернет и интерпретация результатов измерений': 2.509202522331103}, {'Разработка протокола связи для устойчивой передачи видео в самоорганизующихся сетях': 2.509202522331103}, {'Разработка виртуальных моделей измерительных преобразователей': 2.509202522331103}, {'Разработка мобильного модульного программно-аппаратного комплекса для выведения видео- и звуковой информации': 2.509202522331103}, {'Бинарная переключаемая цепь оптических линий задержки, управляющая фазированной решеткой для мобильной связи 5G': 2.509202522331103}, {'Рамановский спектрометр на чипе для экспресс метода диагностики вирусных заболеваний': 2.509202522331103}, {'Квантовый генератор случайных чисел': 2.509202522331103}, {'Оснащение медиацентра МИЭМ': 2.509202522331103}, {'Система мониторинга технического состояния мостов': 2.509202522331103}, {'Элементна ...
